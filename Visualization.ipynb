# %% [markdown]
# # Visualization --- Figure 3 & 4

# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import colormaps as cmaps
import seaborn as sns

# %%
colors_1 = ["#DA6B61", "#9177B4", "#74A1C6", "#78B367", "#DA6B61"]
colors_2 = ["#F0ADAB", "#C1A9D2", "#A7CEE2", "#A3E888", "#F0ADAB"]

# %% [markdown]
# ## Function

# %% [markdown]
# The simulation data are stored in the file "data_1.csv" and "data_2.csv".
#
# The theoretical curves can be obtained by substituting the values provided in the figure captions.

# %%
def Figure_3():
    plt.rcParams.update({
        "text.usetex": False, 
        "font.family": "Times New Roman",
        "text.latex.preamble": r"\usepackage{amsmath}"
    })
    fig, axes = plt.subplots(2, 5, figsize=(22, 10))
    plt.rcParams['font.family'] = 'Times New Roman'
    
    x = np.array([i/20 for i in range(1, 21)])
    y_p = [y_00, y_01, y_02, y_03, y_04]
    y_q = [y_10, y_11, y_12, y_13, y_14]
    
    for col in range(5):
        ax_p = axes[0, col]
        sns.barplot(x=x, y=y_p[col], width=0.7, color=colors_1[col], edgecolor=colors_1[col], linewidth=0, ax=ax_p, alpha=0.9)
        
        ax_q = axes[1, col]
        sns.barplot(x=x, y=y_q[col], width=0.7, color=colors_2[col], edgecolor=colors_2[col], linewidth=0, ax=ax_q, alpha=0.9)
    
    for i in range(2):
        for j in range(5):
            axes[i, j].set_xticklabels([])
    ########################################################################################################################################
    x_f = np.linspace(-1, 21, 500)
    axes[0,0].plot(x_f, y_f_00, color='black', linewidth=1.5)
    axes[0,0].set_title('Independence', fontname='Times New Roman', fontsize=14)
    axes[0,0].annotate('',
                     xy=(0.524*20, 0.05), xycoords='data',
                     xytext=(0.524*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[0,0].text(0.45*20, 0.05052, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[0,0].text(0.56*20, 0.0505, r'= 0.524', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[0,0].set_xlim(-0.5, 19.5)
    axes[0,0].set_ylim(0.048, 0.052)
    axes[0,0].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[1,0].plot(x_f, y_f_10, color='black', linewidth=1.5)
    axes[1,0].set_xlim(-0.5, 19.5)
    axes[1,0].set_ylim(0.048, 0.052)
    axes[1,0].annotate('',
                     xy=(0.139*20, 0.05), xycoords='data',
                     xytext=(0.139*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,0].annotate('',
                     xy=(0.731*20, 0.05), xycoords='data',
                     xytext=(0.731*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,0].text(0.085*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,0].text(0.2*20, 0.0505, r'= 0.139', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,0].text(0.69*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,0].text(0.8*20, 0.0505, r'= 0.731', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,0].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[0,3].plot(x_f, y_f_03, color='black', linewidth=1.5)
    axes[0,3].set_title('Bidirectional influence', fontname='Times New Roman', fontsize=14)
    axes[0,3].set_xlim(-0.5, 19.5)
    axes[0,3].set_ylim(0.048, 0.052)
    axes[0,3].annotate('',
                     xy=(0.524*20, 0.05), xycoords='data',
                     xytext=(0.524*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[0,3].text(0.45*20, 0.05052, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[0,3].text(0.56*20, 0.0505, r'= 0.525', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[0,3].set_yticks(axes[0,3].get_yticks())
    axes[0,3].tick_params(axis='y', labelleft=False) 
    axes[0,3].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[1,3].plot(x_f, y_f_13, color='black', linewidth=1.5)
    axes[1,3].set_xlim(-0.5, 19.5)
    axes[1,3].set_ylim(0.048, 0.052)
    axes[1,3].annotate('',
                     xy=(0.139*20, 0.05), xycoords='data',
                     xytext=(0.139*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,3].annotate('',
                     xy=(0.731*20, 0.05), xycoords='data',
                     xytext=(0.731*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,3].text(0.085*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,3].text(0.2*20, 0.0505, r'= 0.155', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,3].text(0.69*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,3].text(0.8*20, 0.0505, r'= 0.742', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,3].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    axes[1,3].set_yticks(axes[1,3].get_yticks())
    axes[1,3].tick_params(axis='y', labelleft=False) 
    ########################################################################################################################################
    axes[0,1].plot(x_f, y_f_01, color='black', linewidth=1.5)
    axes[0,1].set_xlim(-0.5, 19.5)
    axes[0,1].set_ylim(0.048, 0.052)
    axes[0,1].annotate('',
                     xy=(0.524*20, 0.05), xycoords='data',
                     xytext=(0.524*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[0,1].text(0.45*20, 0.05052, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[0,1].text(0.56*20, 0.0505, r'= 0.524', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[0,1].set_yticks(axes[0,1].get_yticks())
    axes[0,1].tick_params(axis='y', labelleft=False) 
    axes[0,1].set_title('Unidirectional influence (one-to-one)', fontname='Times New Roman', fontsize=14)
    axes[0,1].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[1,1].plot(x_f, y_f_11, color='black', linewidth=1.5)
    axes[1,1].set_xlim(-0.5, 19.5)
    axes[1,1].set_ylim(0.048, 0.052)
    axes[1,1].annotate('',
                     xy=(0.611*20, 0.05), xycoords='data',
                     xytext=(0.611*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,1].text(0.558*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,1].text(0.67*20, 0.0505, r'= 0.611', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,1].set_yticks(axes[1,1].get_yticks())
    axes[1,1].tick_params(axis='y', labelleft=False)
    axes[1,1].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[0,2].plot(x_f, y_f_02, color='black', linewidth=1.5)
    axes[0,2].set_xlim(-0.5, 19.5)
    axes[0,2].set_ylim(0.048, 0.052)
    axes[0,2].annotate('',
                     xy=(0.524*20, 0.05), xycoords='data',
                     xytext=(0.524*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[0,2].text(0.45*20, 0.05052, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[0,2].text(0.56*20, 0.0505, r'= 0.524', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[0,2].set_yticks(axes[0,2].get_yticks())
    axes[0,2].tick_params(axis='y', labelleft=False)
    axes[0,2].set_title('Unidirectional influence (one-to-three)', fontname='Times New Roman', fontsize=14)
    axes[0,2].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[1,2].plot(x_f, y_f_12, color='black', linewidth=1.5)
    axes[1,2].set_xlim(-0.5, 19.5)
    axes[1,2].set_ylim(0.048, 0.052)
    axes[1,2].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    axes[1,2].annotate('',
                     xy=(0.139*20, 0.05), xycoords='data',
                     xytext=(0.139*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,2].annotate('',
                     xy=(0.731*20, 0.05), xycoords='data',
                     xytext=(0.731*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,2].text(0.085*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,2].text(0.2*20, 0.0505, r'= 0.139', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,2].text(0.685*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,2].text(0.8*20, 0.0505, r'= 0.731', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,2].set_yticks(axes[1,2].get_yticks())
    axes[1,2].tick_params(axis='y', labelleft=False)
    ########################################################################################################################################
    axes[0,4].plot(x_f, y_f_04, color='black', linewidth=1.5)
    axes[0,4].set_xlim(-0.5, 19.5)
    axes[0,4].set_ylim(0.048, 0.052)
    axes[0,4].annotate('',
                     xy=(0.525*20, 0.05), xycoords='data',
                     xytext=(0.525*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[0,4].text(0.45*20, 0.05052, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[0,4].text(0.56*20, 0.0505, r'= 0.525', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[0,4].set_yticks(axes[0,4].get_yticks())
    axes[0,4].tick_params(axis='y', labelleft=False)
    axes[0,4].set_title('Independence', fontname='Times New Roman', fontsize=14)
    axes[0,4].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    ########################################################################################################################################
    axes[1,4].plot(x_f, y_f_14, color='black', linewidth=1.5)
    axes[1,4].set_xlim(-0.5, 19.5)
    axes[1,4].set_ylim(0.048, 0.052)
    axes[1,4].axhline(y=0.05, color='black', linestyle='--', linewidth=0.75)
    axes[1,4].annotate('',
                     xy=(0.151*20, 0.05), xycoords='data',
                     xytext=(0.151*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,4].text(0.085*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,4].text(0.2*20, 0.0505, r'= 0.151', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,4].annotate('',
                     xy=(0.739*20, 0.05), xycoords='data',
                     xytext=(0.739*20, 0.0504), textcoords='data',
                     arrowprops=dict(edgecolor='black', facecolor='black', shrink=0.05, headwidth=6, headlength=10, width=1))
    axes[1,4].text(0.69*20, 0.05052, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black', style='italic')
    axes[1,4].text(0.8*20, 0.0505, r'= 0.739', ha='center', va='center', fontname='Times New Roman', fontsize=12, color='black')
    axes[1,4].set_yticks(axes[1,4].get_yticks())
    axes[1,4].tick_params(axis='y', labelleft=False)
    ########################################################################################################################################
    fig.text(0.555, 0.49, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=16, style='italic')
    fig.text(0.5, 0.49, r'Cooperation probability,', ha='center', va='center', fontname='Times New Roman', fontsize=16)
    fig.text(0.5, 0.07, r'Cooperation probability,', ha='center', va='center', fontname='Times New Roman', fontsize=16)
    fig.text(0.555, 0.07, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=16, style='italic')
    fig.text(0.09, 0.5, r'Frequency', ha='center', va='center', rotation=90, fontname='Times New Roman', fontsize=16)
    fig.text(0.1285, 0.515, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.2555, 0.515, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.189, 0.515, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.1555, 0.515, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.2225, 0.515, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.289, 0.515, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.416, 0.515, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.3495, 0.515, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.316, 0.515, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.383, 0.515, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.4495, 0.515, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.5765, 0.515, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.51, 0.515, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.4765, 0.515, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.5435, 0.515, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.61, 0.515, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.737, 0.515, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.6705, 0.515, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.637, 0.515, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.704, 0.515, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.7705, 0.515, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.8975, 0.515, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.831, 0.515, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.7975, 0.515, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.8645, 0.515, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.1285, 0.095, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.2555, 0.095, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.189, 0.095, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.1555, 0.095, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.2225, 0.095, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.289, 0.095, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.416, 0.095, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.3495, 0.095, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.316, 0.095, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.383, 0.095, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.4495, 0.095, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.5765, 0.095, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.51, 0.095, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.4765, 0.095, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.5435, 0.095, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.61, 0.095, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.737, 0.095, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.6705, 0.095, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.637, 0.095, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.704, 0.095, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.7705, 0.095, r'0.05', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.8975, 0.095, r'1.00', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.831, 0.095, r'0.50', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.7975, 0.095, r'0.25', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.8645, 0.095, r'0.75', ha='center', va='center', fontname='Times New Roman', fontsize=10)
    fig.text(0.434, 0.93, r'Non-concurrent', ha='center', va='center', fontname='Times New Roman', fontsize=23)
    fig.text(0.834, 0.93, r'Concurrent', ha='center', va='center', fontname='Times New Roman', fontsize=23)
    fig.lines.append(plt.Line2D([0.7533, 0.7533], [0.05, 0.95], transform=fig.transFigure, color="black", linestyle="--"))
    #plt.savefig('Fig_3.png', format='png', dpi = 400, bbox_inches='tight')
    plt.show()

# %%
def Figure_4():
    fig, axes = plt.subplots(2, 5, figsize=(22, 10))
    plt.rcParams['font.family'] = 'Times New Roman'
    plt.rcParams['font.style'] = 'italic'
    ########################################################################################################################################
    z = [0.02, 0.06, 0.2, 0.4, 1]
    axes[0,0].scatter(z, p_00_1, s=60, marker='^', edgecolors=colors_1[0], facecolors=colors_1[0], zorder=4)
    axes[0,0].scatter(z, p_00_2, s=60, marker='s', edgecolors=colors_2[0], facecolors=colors_2[0], zorder=3)
    plt.rcParams['font.family'] = 'Times New Roman'
    plt.rcParams['font.style'] = 'italic'
    axes[0,0].plot(x, y_00_1, color=colors_1[0], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[0,0].plot(x, y_00_2, color=colors_2[0], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.family'] = 'Times New Roman'
    plt.rcParams['font.style'] = 'normal'
    axes[0,0].set_xlim(0.01, 1.1)
    axes[0,0].set_ylim(0.49, 0.502)
    axes[0,0].tick_params(axis='both', which='major', labelsize=10)
    axes[0,0].set_xscale('log')
    axes[0,0].legend(loc = 'right')
    axes[0,0].set_title('Independence', fontname='Times New Roman', fontsize=14)
    axes[0,0].text(0.77, 0.4964, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[0,0].text(0.77, 0.4957, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[1,0].scatter(z, p_10_1, s=60, marker='^', edgecolors=colors_1[0], facecolors=colors_1[0], zorder=4)
    axes[1,0].scatter(z, p_10_2, s=60, marker='s', edgecolors=colors_2[0], facecolors=colors_2[0], zorder=3)
    plt.rcParams['font.style'] = 'italic'
    axes[1,0].plot(x, y_10_1, color=colors_1[0], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[1,0].plot(x, y_10_2, color=colors_2[0], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[1,0].set_xlim(0.01, 1.1)
    axes[1,0].set_ylim(0.494, 0.5)
    axes[1,0].tick_params(axis='both', which='major', labelsize=10)
    axes[1,0].set_xscale('log')
    axes[1,0].legend(loc = 'right')
    axes[1,0].text(0.77, 0.4972, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[1,0].text(0.77, 0.49685, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[0,2].scatter(z, p_02_1, s=60, marker='^', edgecolors=colors_1[2], facecolors=colors_1[2], zorder=4)
    axes[0,2].scatter(z, p_02_2, s=60, marker='s', edgecolors=colors_2[2], facecolors=colors_2[2], zorder=3)  
    plt.rcParams['font.style'] = 'italic'
    axes[0,2].plot(x, y_02_1, color=colors_1[2], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[0,2].plot(x, y_02_2, color=colors_2[2], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[0,2].set_xlim(0.01, 1.1)
    axes[0,2].set_ylim(0.49, 0.502)
    axes[0,2].tick_params(axis='both', which='major', labelsize=10)
    axes[0,2].set_xscale('log')
    axes[0,2].legend(loc = 'right')
    axes[0,2].set_title('Unidirectional influence (one-to-three)', fontname='Times New Roman', fontsize=14)
    axes[0,2].set_yticks(axes[0,2].get_yticks())
    axes[0,2].tick_params(axis='y', labelleft=False)
    axes[0,2].text(0.77, 0.4964, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[0,2].text(0.77, 0.4957, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[1,2].scatter(z, p_12_1, s=60, marker='^', edgecolors=colors_1[2], facecolors=colors_1[2], zorder=4)
    axes[1,2].scatter(z, p_12_2, s=60, marker='s', edgecolors=colors_2[2], facecolors=colors_2[2], zorder=3)
    plt.rcParams['font.style'] = 'italic'
    axes[1,2].plot(x, y_12_1, color=colors_1[2], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[1,2].plot(x, y_12_2, color=colors_2[2], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[1,2].set_xlim(0.01, 1.1)
    axes[1,2].set_ylim(0.494, 0.5)
    axes[1,2].tick_params(axis='both', which='major', labelsize=10)
    axes[1,2].set_xscale('log')
    axes[1,2].legend(loc = 'right')
    axes[1,2].set_yticks(axes[1,2].get_yticks())
    axes[1,2].tick_params(axis='y', labelleft=False)
    axes[1,2].text(0.77, 0.4972, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[1,2].text(0.77, 0.49685, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[0,1].scatter(z, p_01_1, s=60, marker='^', edgecolors=colors_1[1], facecolors=colors_1[1], zorder = 4)
    axes[0,1].scatter(z, p_01_2, s=60, marker='s', edgecolors=colors_2[1], facecolors=colors_2[1], zorder=3)
    plt.rcParams['font.style'] = 'italic'
    axes[0,1].plot(x, y_01_1, color=colors_1[1], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[0,1].plot(x, y_01_2, color=colors_2[1], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'    
    axes[0,1].set_xlim(0.01, 1.1)
    axes[0,1].set_ylim(0.49, 0.502)
    axes[0,1].tick_params(axis='both', which='major', labelsize=10)
    axes[0,1].set_xscale('log')
    axes[0,1].legend(loc = 'right')
    axes[0,1].set_title('Unidirectional influence (one-to-one)', fontname='Times New Roman', fontsize=14)
    axes[0,1].set_yticks(axes[0,1].get_yticks())
    axes[0,1].tick_params(axis='y', labelleft=False)
    axes[0,1].text(0.77, 0.4964, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[0,1].text(0.77, 0.4957, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[1,1].scatter(z, p_11_1, s=60, marker='^', edgecolors=colors_1[1], facecolors=colors_1[1], zorder = 4)
    axes[1,1].scatter(z, p_11_2, s=60, marker='s', edgecolors=colors_2[1], facecolors=colors_2[1], zorder=3)    
    plt.rcParams['font.style'] = 'italic'
    axes[1,1].plot(x, y_11_1, color=colors_1[1], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[1,1].plot(x, y_11_2, color=colors_2[1], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'    
    axes[1,1].set_xlim(0.01, 1.1)
    axes[1,1].set_ylim(0.494, 0.5)
    axes[1,1].tick_params(axis='both', which='major', labelsize=10)
    axes[1,1].set_xscale('log')
    axes[1,1].legend(loc = 'right')
    axes[1,1].set_yticks(axes[1,1].get_yticks())
    axes[1,1].tick_params(axis='y', labelleft=False)
    axes[1,1].text(0.77, 0.4972, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[1,1].text(0.77, 0.49685, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[0,3].scatter(z, p_03_1, s=60, marker='^', edgecolors=colors_1[3], facecolors=colors_1[3], zorder = 4)
    axes[0,3].scatter(z, p_03_2, s=60, marker='s', edgecolors=colors_2[3], facecolors=colors_2[3], zorder=3)
    plt.rcParams['font.style'] = 'italic'
    axes[0,3].plot(x, y_03_1, color=colors_1[3], label = r'$\langle\,\;\,\,\rangle$', linewidth=3, alpha = 0.6, zorder=1)
    axes[0,3].plot(x, y_03_2, color=colors_2[3], label = r'$\langle\,\;\,\,\rangle$', linewidth=1, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[0,3].set_xlim(0.01, 1.1)
    axes[0,3].set_ylim(0.49, 0.502)
    axes[0,3].tick_params(axis='both', which='major', labelsize=10)
    axes[0,3].set_xscale('log')
    axes[0,3].legend(loc = 'right')
    axes[0,3].set_title('Bidirectional influence', fontname='Times New Roman', fontsize=14)
    axes[0,3].set_yticks(axes[0,3].get_yticks())
    axes[0,3].tick_params(axis='y', labelleft=False)
    axes[0,3].text(0.77, 0.4964, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[0,3].text(0.77, 0.4957, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[1,3].scatter(z, p_13_1, s=60, marker='^', edgecolors=colors_1[3], facecolors=colors_1[3], zorder = 4)
    axes[1,3].scatter(z, p_13_2, s=60, marker='s', edgecolors=colors_2[3], facecolors=colors_2[3], zorder=3)    
    plt.rcParams['font.style'] = 'italic'
    axes[1,3].plot(x, y_13_1, color=colors_1[3], label = r'$\langle\,\;\,\,\rangle$', linewidth=3, alpha = 0.6, zorder=1)
    axes[1,3].plot(x, y_13_2, color=colors_2[3], label = r'$\langle\,\;\,\,\rangle$', linewidth=1, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[1,3].set_xlim(0.01, 1.1)
    axes[1,3].set_ylim(0.494, 0.5)
    axes[1,3].tick_params(axis='both', which='major', labelsize=10)
    axes[1,3].set_xscale('log')
    axes[1,3].legend(loc = 'right')
    axes[1,3].set_yticks(axes[1,3].get_yticks())
    axes[1,3].tick_params(axis='y', labelleft=False)
    axes[1,3].text(0.77, 0.4972, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[1,3].text(0.77, 0.49685, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[0,4].scatter(z, p_04_1, s=60, marker='^', edgecolors=colors_1[4], facecolors=colors_1[4], zorder = 4)
    axes[0,4].scatter(z, p_04_2, s=60, marker='s', edgecolors=colors_2[4], facecolors=colors_2[4], zorder=3)
    plt.rcParams['font.style'] = 'italic'
    axes[0,4].plot(x, y_04_1, color=colors_1[4], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[0,4].plot(x, y_04_2, color=colors_2[4], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[0,4].set_xlim(0.01, 1.1)
    axes[0,4].set_ylim(0.49, 0.502)
    axes[0,4].tick_params(axis='both', which='major', labelsize=10)
    axes[0,4].set_xscale('log')
    axes[0,4].legend(loc = 'right')
    axes[0,4].set_title('Independence', fontname='Times New Roman', fontsize=14)
    axes[0,4].set_yticks(axes[0,4].get_yticks())
    axes[0,4].tick_params(axis='y', labelleft=False)
    axes[0,4].text(0.77, 0.4964, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[0,4].text(0.77, 0.4957, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    axes[1,4].scatter(z, p_14_1, s=60, marker='^', edgecolors=colors_1[4], facecolors=colors_1[4], zorder = 4)
    axes[1,4].scatter(z, p_14_2, s=60, marker='s', edgecolors=colors_2[4], facecolors=colors_2[4], zorder=3)
    plt.rcParams['font.style'] = 'italic'
    axes[1,4].plot(x, y_14_1, color=colors_1[4], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=1)
    axes[1,4].plot(x, y_14_2, color=colors_2[4], label = r'$\langle\,\;\,\,\rangle$', linewidth=1.5, zorder=2)
    plt.rcParams['font.style'] = 'normal'
    axes[1,4].set_xlim(0.01, 1.1)
    axes[1,4].set_ylim(0.494, 0.5)
    axes[1,4].tick_params(axis='both', which='major', labelsize=10)
    axes[1,4].set_xscale('log')
    axes[1,4].legend(loc = 'right')
    axes[1,4].set_yticks(axes[1,4].get_yticks())
    axes[1,4].tick_params(axis='y', labelleft=False)
    axes[1,4].text(0.77, 0.4972, r'p', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    axes[1,4].text(0.77, 0.49685, r'q', ha='center', va='center', fontname='Times New Roman', fontsize=11, 
                   color='black', style='italic', zorder=10)
    ########################################################################################################################################
    fig.text(0.485, 0.49, r'Strategy mutation probability,', ha='center', va='center', fontname='Times New Roman', fontsize=16)
    fig.text(0.551, 0.49, r'u', ha='center', va='center', fontname='Times New Roman', fontsize=16, style='italic')
    fig.text(0.485, 0.07, r'Phenotypic mutation probability,', ha='center', va='center', fontname='Times New Roman', fontsize=16)
    fig.text(0.5555, 0.07, r'v', ha='center', va='center', fontname='Times New Roman', fontsize=16, style='italic')
    fig.text(0.09, 0.5, r'Population average', ha='center', va='center', rotation=90, fontname='Times New Roman', fontsize=16)
    fig.text(0.434, 0.93, r'Non-concurrent', ha='center', va='center', fontname='Times New Roman', fontsize=23)
    fig.text(0.834, 0.93, r'Concurrent', ha='center', va='center', fontname='Times New Roman', fontsize=23)
    fig.lines.append(plt.Line2D([0.7533, 0.7533], [0.05, 0.95], transform=fig.transFigure, color="black", linestyle="--"))
    #plt.savefig('Fig_4.png', format='png', dpi = 400, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Paint

# %%
Figure_3()

# %%
Figure_4()

# %% [markdown]
# #### Theoretical curves

# %%
#x_f = np.linspace(-1, 21, 500)
#y_f_00 = (-(125/7)*(x_f/20)**2 - (32875/756)*(x_f/20) + (41875/1512))*0.00048/20 + 1/20
#y_f_10 = (-(375/7)*(x_f/20)**2 + (5875/126)*(x_f/20) - (1375/252))*0.00048/20 + 1/20
#y_f_01 = (-(125/7)*(x_f/20)**2 - (32875/756)*(x_f/20) + (41875/1512))*0.00048/20 + 1/20
#y_f_11 = (-(1403275/21546)*(x_f/20)**2 + (505525/21546)*(x_f/20) + (1289975/129276))*0.00048/20 + 1/20
#y_f_02 = (-(125/7)*(x_f/20)**2 - (32875/756)*(x_f/20) + (41875/1512))*0.00048/20 + 1/20
#y_f_12 = (-(375/7)*(x_f/20)**2 + (5875/126)*(x_f/20) - (1375/252))*0.00048/20 + 1/20
#y_f_03 = (-(125/7)*(x_f/20)**2 - (32875/756)*(x_f/20) + (41875/1512))*0.00048/20 + 1/20
#y_f_13 = (-(375/7)*(x_f/20)**2 + (5875/126)*(x_f/20) - (1375/252))*0.00048/20 + 1/20
#y_f_04 = (-(17.7469135802469)*(x_f/20)**2 - (41.2379972565158)*(x_f/20) + (26.5346364883402))*0.00048/20 + 0.05
#y_f_14 = (-(53.2924107142857)*(x_f/20)**2 + (47.4330357142857)*(x_f/20) - (5.95238095238095))*0.00048/20 + 0.05

#x = np.linspace(0.01, 1.5, 1000)
#y_00_1 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(15*(50*x)**2+69*(50*x)+48))/(192*(50*x+1)*(50*x+2)*(50*x+4)))
#y_00_2 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(12*(50*x)**2+58*(50*x)+48))/(144*(50*x+1)*(50*x+2)*(50*x+4)))
#y_10_1 = 1/2 - 0.00048*((125*(3*(50*x)**3+15*(50*x)**2+48*(50*x)+180))/(144*(50*x+1)*(50*x+3)*(50*x+5)))
#y_10_2 = 1/2 - 0.00048*((125*(3*(50*x)**3+19*(50*x)**2+55*(50*x)+135))/(108*(50*x+1)*(50*x+3)*(50*x+5)))
#y_01_1 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(15*(50*x)**2+69*(50*x)+48))/(192*(50*x+1)*(50*x+2)*(50*x+4)))
#y_01_2 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(6*(50*x)**2+36*(50*x)+48))/(48*(50*x+1)*(50*x+2)*(50*x+4)))
#y_11_1 = 1/2 - 0.00048*((125*(3*(50*x)**3+15*(50*x)**2+48*(50*x)+180))/(144*(50*x+1)*(50*x+3)*(50*x+5)))
#y_11_2 = 1/2 - 0.00048*((125*(3*(50*x)**3+27*(50*x)**2+69*(50*x)+45))/(36*(50*x+1)*(50*x+3)*(50*x+5)))
#y_02_1 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(15*(50*x)**2+69*(50*x)+48))/(192*(50*x+1)*(50*x+2)*(50*x+4)))
#y_02_2 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(12*(50*x)**2+58*(50*x)+48))/(144*(50*x+1)*(50*x+2)*(50*x+4)))
#y_12_1 = 1/2 - 0.00048*((125*(3*(50*x)**3+15*(50*x)**2+48*(50*x)+180))/(144*(50*x+1)*(50*x+3)*(50*x+5)))
#y_12_2 = 1/2 - 0.00048*((125*(3*(50*x)**3+19*(50*x)**2+55*(50*x)+135))/(108*(50*x+1)*(50*x+3)*(50*x+5)))
#y_03_1 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(12*(50*x)**2+58*(50*x)+48))/(144*(50*x+1)*(50*x+2)*(50*x+4)))
#y_03_2 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(12*(50*x)**2+58*(50*x)+48))/(144*(50*x+1)*(50*x+2)*(50*x+4)))
#y_13_1 = 1/2 - 0.00048*((125*(3*(50*x)**3+19*(50*x)**2+55*(50*x)+135))/(108*(50*x+1)*(50*x+3)*(50*x+5)))
#y_13_2 = 1/2 - 0.00048*((125*(3*(50*x)**3+19*(50*x)**2+55*(50*x)+135))/(108*(50*x+1)*(50*x+3)*(50*x+5)))
#y_04_1 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(44.5*(50*x)**2+202.8333333333*(50*x)+136))/(576*(50*x+1)*(50*x+2)*(50*x+4)))
#y_04_2 = 1/2 - (0.001*(1-x)/(50*x))*((125*(50*x)*(47.25*(50*x)**2+225.75*(50*x)+180))/(576*(50*x+1)*(50*x+2)*(50*x+4)))
#y_14_1 = 1/2 - 0.00048*((125*(8.5*(50*x)**3+39.833333333333*(50*x)**2+131.33333333333*(50*x)+540))/(432*(50*x+1)*(50*x+3)*(50*x+5)))
#y_14_2 = 1/2 - 0.00048*((125*(11.25*(50*x)**3+68.25*(50*x)**2+201*(50*x)+540))/(432*(50*x+1)*(50*x+3)*(50*x+5)))
